# %% [markdown]
# GitHub Repository on Linear Regression

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("Ice Cream.csv")

# %%
df.head()
# Out:
#    Temperature  Revenue
# 0         24.6      535
# 1         26.1      626
# 2         27.8      661
# 3         20.6      488
# 4         11.6      317

# %%
df.head(10)
# Out:
#    Temperature  Revenue
# 0         24.6      535
# 1         26.1      626
# 2         27.8      661
# 3         20.6      488
# 4         11.6      317
# 5         14.4      368
# 6         13.8      309
# 7         30.9      697
# 8          1.0       56
# 9         31.7      738

# %%
plt.scatter(df["Temperature"], df["Revenue"])
plt.xlabel("Temperature")
plt.ylabel("Revenue")
plt.show()

# %%
X = df.iloc[:, 0:1]
y = df.iloc[:, -1]

# %%
X
# Out:
#      Temperature
# 0           24.6
# 1           26.1
# 2           27.8
# 3           20.6
# 4           11.6
# ..           ...
# 495         22.3
# 496         32.9
# 497         12.6
# 498         22.4
# 499         29.0
#
# [500 rows x 1 columns]

# %%
y
# Out:
# 0      535
# 1      626
# 2      661
# 3      488
# 4      317
#       ...
# 495    525
# 496    756
# 497    307
# 498    567
# 499    656
# Name: Revenue, Length: 500, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(X_test)

# %%
y_pred
# Out:
# array([736.75181385, 655.50932491, 711.09629103, 582.81867691,
#        507.99006867, 486.61046632, 604.19827926, 388.26429549,
#        796.61470044, 597.78439855, 512.26598914, 520.81783008,
#        283.50424396, 484.47250608, 672.61300679, 591.37051785,
#        495.16230726, 493.02434702, 659.78524538, 503.7141482 ,
#        569.99091549, 354.05693172, 253.57280066, 285.64220419,
#        187.29603337, 369.02265337, 679.0268875 , 448.12718208,
#        364.7467329 , 591.37051785, 473.7827049 , 480.19658561,
#        606.3362395 , 550.74927338, 623.43992138, 401.0920569 ,
#        486.61046632, 584.95663714, 262.1246416 , 548.61131314,
#        531.50763126, 557.16315408, 409.64389784, 672.61300679,
#        631.99176232, 679.0268875 , 458.81698326, 270.67648254,
#        467.3688242 , 527.23171079, 708.95833079, 661.92320561,
#        418.19573878, 478.05862537, 589.23255761, 745.30365479,
#        234.33115854, 296.33200537, 749.57957526, 651.23340444,
#        307.02180655, 738.88977409, 499.43822773, 520.81783008,
#        525.09375055, 512.26598914, 445.98922184, 471.64474467,
#        540.0594722 , 452.40310255, 234.33115854, 593.50847808,
#        319.84956796, 572.12887573, 439.57534114, 309.15976678,
#        448.12718208, 892.82291103, 610.61215997, 413.91981831,
#        939.85803621, 599.92235879, 480.19658561, 450.26514231,
#        537.92151196, 758.13141621, 379.71245455, 475.92066514,
#        422.47165925, 548.61131314, 640.54360326, 452.40310255,
#        510.1280289 , 424.60961949, 604.19827926, 362.60877266,
#        674.75096703, 892.82291103, 698.26852962, 676.88892726])

# %%
lr.predict(X_test.iloc[1].values.reshape(1, 1))
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([655.50932491])

# %%
plt.scatter(df["Temperature"], df["Revenue"])
plt.plot(X_train, lr.predict(X_train), color="red")
plt.xlabel("Temperature")
plt.ylabel("Revenue")
plt.show()
